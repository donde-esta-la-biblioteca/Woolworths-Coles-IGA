# %%
from rapidfuzz.process import extractOne
from rapidfuzz import fuzz
import pandas as pd

# %%
df_wow = pd.read_csv('2. Modified Data/Modified Woolworths.csv').fillna('')
df_coles = pd.read_csv('2. Modified Data/Modified Coles.csv').fillna('')
df_iga = pd.read_csv('2. Modified Data/Modified IGA.csv')

# %% [markdown]
# ## Func/Testing

# %%
def find_fuzzymatch(item, choices):
     return extractOne(item, choices, scorer=fuzz.token_sort_ratio, score_cutoff=70)

# %%
# Testing and seeing what the function outputs

# for item in df_iga['Brand_Product_Size']:
#     results_tuple = find_fuzzymatch(item, df_coles['Brand_Product_Size'])
#     try:
#         print(results_tuple[0], results_tuple[1])
#     except:
#         print('None')

# %%
def get_fuzzymatches(target_df, comparison_df):
    
    target_df['FuzzyProduct Match'] = target_df['Brand_Product_Size'].apply(lambda x: find_fuzzymatch(x, comparison_df['Brand_Product_Size']))
   
    return target_df

# %% [markdown]
# ### Performace Comparison - Original FuzzyWuzzy (Python implementation) vs RapidFuzz (Fully implemented in C++)

# %% [markdown]
# #### Timing RapidFuzz - IGA vs Coles

# %%
# %%timeit -r1 -n1
# get_fuzzymatches(df_iga, df_coles)

# %% [markdown]
# #### Timing FuzzyWuzzy - IGA vs Coles

# %%
# from fuzzywuzzy import process
# from fuzzywuzzy import fuzz as fz

# %%
# def slow_find_fuzzymatch(item, choices):
#     return process.extractOne(item, choices, scorer=fz.token_sort_ratio, score_cutoff=70)

# %%
# def slow_get_fuzzymatches(target_df, comparison_df):
    
#     target_df['FuzzyProduct Match'] = target_df['Brand_Product_Size'].apply(lambda x: slow_find_fuzzymatch(x, comparison_df['Brand_Product_Size']))
   
#     return target_df

# %%
# %%timeit -r1 -n1
# slow_get_fuzzymatches(df_iga, df_coles)

# %% [markdown]
# ### Results
# * For the exact same operation:
#     * RapidFuzz took 47 secs
#     * FuzzyWuzzy took 455 secs
# * The above results show that RapidFuzz is about 10x faster than the original FuzzyWuzzy package coded in pure Python.
# * It has all the functions FuzzyWuzzy has and the syntax is almost exactly the same.

# %% [markdown]
# ## Fuzzy Matching Coles and Woolworths

# %%
fuzzy_coles_wow = get_fuzzymatches(df_coles, df_wow).copy()

# %%
fuzzy_coles_wow['Product Match'] = fuzzy_coles_wow['FuzzyProduct Match'].apply(lambda x: x[0] if x is not None else '')
fuzzy_coles_wow['Match Score'] = fuzzy_coles_wow['FuzzyProduct Match'].apply(lambda x: int(x[1]) if x is not None else '')

# %%
fuzzy_coles_wow.head()
# Out:
#         SKU                                 Brand_Product_Size  \
# 0  3980255P  Head & Shoulders Conditioner Smooth & Silky 660mL
# 1  3838775P                          Coles Jujube Prepack 400g
# 2  6046740P              Fantastic Crispy Bacon Noodle Cup 70g
# 3   403765P    McCain Frozen Ham & Pineapple Family Pizza 500g
# 4  3274024P  Perfect Italiano Grated Cheese Perfect Bakes 250g
#
#               Brand                         Product Name  COL Price  \
# 0  Head & Shoulders           Conditioner Smooth & Silky      17.00
# 1             Coles                       Jujube Prepack       9.90
# 2         Fantastic              Crispy Bacon Noodle Cup       1.60
# 3            McCain  Frozen Ham & Pineapple Family Pizza       5.50
# 4  Perfect Italiano          Grated Cheese Perfect Bakes       4.25
#
#            COL ppu COL Size COL Specials         COL Category  \
# 0  $2.58 per 100mL    660mL                   Health & Beauty
# 1   $24.75 per 1Kg     400g                       Fruit & Veg
# 2   $2.29 per 100G      70g                            Pantry
# 3   $1.10 per 100G     500g     Specials               Frozen
# 4   $17.00 per 1Kg     250g     Specials  Dairy Eggs & Fridge
#
#                                          Product URL  \
# 0  https://shop.coles.com.au/a/national/product/s...
# 1  https://shop.coles.com.au/a/national/product/f...
# 2  https://shop.coles.com.au/a/national/product/f...
# 3  https://shop.coles.com.au/a/national/product/m...
# 4  https://shop.coles.com.au/a/national/product/p...
#
#                                   FuzzyProduct Match  \
# 0  (Head & Shoulders Smooth & Silky Conditioner 6...
# 1                                               None
# 2  (Fantastic Crispy Bacon Noodle Cup 70g, 100.0,...
# 3  (Mccain Pizza Ham & Pineapple 500g, 81.5789473...
# 4  (Perfect Italiano Perfect Bakes 3 Cheeses 450g...
#
#                                        Product Match Match Score
# 0  Head & Shoulders Smooth & Silky Conditioner 660mL         100
# 1
# 2              Fantastic Crispy Bacon Noodle Cup 70g         100
# 3                  Mccain Pizza Ham & Pineapple 500g          81
# 4      Perfect Italiano Perfect Bakes 3 Cheeses 450g          87

# %%
coles_wow_fuzzymatched = fuzzy_coles_wow[[
        'SKU', 'Brand', 'Product Name', 'Brand_Product_Size', 'Product Match', 'Match Score', 'COL Price', 
        'COL ppu', 'COL Size', 'COL Specials', 'COL Category', 'Product URL'
    ]]
coles_wow_fuzzymatched = coles_wow_fuzzymatched.rename(columns={'Product Match': 'WOW Product Match'})

# %%
coles_wow_fuzzymatched.head()
# Out:
#         SKU             Brand                         Product Name  \
# 0  3980255P  Head & Shoulders           Conditioner Smooth & Silky
# 1  3838775P             Coles                       Jujube Prepack
# 2  6046740P         Fantastic              Crispy Bacon Noodle Cup
# 3   403765P            McCain  Frozen Ham & Pineapple Family Pizza
# 4  3274024P  Perfect Italiano          Grated Cheese Perfect Bakes
#
#                                   Brand_Product_Size  \
# 0  Head & Shoulders Conditioner Smooth & Silky 660mL
# 1                          Coles Jujube Prepack 400g
# 2              Fantastic Crispy Bacon Noodle Cup 70g
# 3    McCain Frozen Ham & Pineapple Family Pizza 500g
# 4  Perfect Italiano Grated Cheese Perfect Bakes 250g
#
#                                    WOW Product Match Match Score  COL Price  \
# 0  Head & Shoulders Smooth & Silky Conditioner 660mL         100      17.00
# 1                                                                      9.90
# 2              Fantastic Crispy Bacon Noodle Cup 70g         100       1.60
# 3                  Mccain Pizza Ham & Pineapple 500g          81       5.50
# 4      Perfect Italiano Perfect Bakes 3 Cheeses 450g          87       4.25
#
#            COL ppu COL Size COL Specials         COL Category  \
# 0  $2.58 per 100mL    660mL                   Health & Beauty
# 1   $24.75 per 1Kg     400g                       Fruit & Veg
# 2   $2.29 per 100G      70g                            Pantry
# 3   $1.10 per 100G     500g     Specials               Frozen
# 4   $17.00 per 1Kg     250g     Specials  Dairy Eggs & Fridge
#
#                                          Product URL
# 0  https://shop.coles.com.au/a/national/product/s...
# 1  https://shop.coles.com.au/a/national/product/f...
# 2  https://shop.coles.com.au/a/national/product/f...
# 3  https://shop.coles.com.au/a/national/product/m...
# 4  https://shop.coles.com.au/a/national/product/p...

# %%
coles_wow_fuzzymatched.to_csv('3. Fuzzy Matching/Token Sort/Coles_Woolworths.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Woolworth-Coles (reverse of above)

# %%
fuzzy_wow_coles = get_fuzzymatches(df_wow, df_coles).copy()

# %%
fuzzy_wow_coles['Product Match'] = fuzzy_wow_coles['FuzzyProduct Match'].apply(lambda x: x[0] if x is not None else '')
fuzzy_wow_coles['Match Score'] = fuzzy_wow_coles['FuzzyProduct Match'].apply(lambda x: int(x[1]) if x is not None else '')

# %%
fuzzy_wow_coles.head()
# Out:
#       SKU                                 Brand_Product_Size  \
# 0  814139          Em Wholefoods Hemp Oil Cold Pressed 250mL
# 1   84972  Happy Little Camper Newborn Natural Nappies 36...
# 2   95412            Spc Spaghetti Rich Tomato 140g x12 pack
# 3   99040               Mint Glazed Antipasto Dish Blue each
# 4  808305                Seedlip Grove 42 Alcohol Free 700mL
#
#                  Brand                                 Product Name  \
# 0        em wholefoods          Em Wholefoods Hemp Oil Cold Pressed
# 1  happy little camper  Happy Little Camper Newborn Natural Nappies
# 2                  spc                    Spc Spaghetti Rich Tomato
# 3                 mint              Mint Glazed Antipasto Dish Blue
# 4              seedlip                Seedlip Grove 42 Alcohol Free
#
#    WOW Price       WOW Size        WOW ppu WOW Specials WOW Category  \
# 0      19.95          250mL  $7.98 / 100ML                    Pantry
# 1      14.00        36 pack    $0.39 / 1EA                      Baby
# 2      10.50  140g x12 pack   $0.63 / 100G                    Pantry
# 3       2.00           each                               NOT LISTED
# 4      50.00          700mL    $71.43 / 1L                    Drinks
#
#   Online Only New Product                                        Product URL  \
# 0                          https://www.woolworths.com.au/shop/productdeta...
# 1                          https://www.woolworths.com.au/shop/productdeta...
# 2                          https://www.woolworths.com.au/shop/productdeta...
# 3                          https://www.woolworths.com.au/shop/productdeta...
# 4                          https://www.woolworths.com.au/shop/productdeta...
#
#                                   FuzzyProduct Match  \
# 0  (Soulseed Cold Pressed Hemp Oil 250mL, 83.1168...
# 1                                               None
# 2  (SPC Spaghetti in Rich Tomato 4 pack 220g, 83....
# 3                                               None
# 4                                               None
#
#                               Product Match Match Score
# 0      Soulseed Cold Pressed Hemp Oil 250mL          83
# 1
# 2  SPC Spaghetti in Rich Tomato 4 pack 220g          83
# 3
# 4

# %%
wow_coles_fuzzymatched = fuzzy_wow_coles[[
        'SKU', 'Brand', 'Product Name', 'Brand_Product_Size', 'Product Match', 'Match Score', 'WOW Price', 
        'WOW ppu', 'WOW Size', 'WOW Specials', 'WOW Category', 'Product URL'
    ]]
wow_coles_fuzzymatched = wow_coles_fuzzymatched.rename(columns={'Product Match': 'COL Product Match'})

# %%
wow_coles_fuzzymatched.head()
# Out:
#       SKU                Brand                                 Product Name  \
# 0  814139        em wholefoods          Em Wholefoods Hemp Oil Cold Pressed
# 1   84972  happy little camper  Happy Little Camper Newborn Natural Nappies
# 2   95412                  spc                    Spc Spaghetti Rich Tomato
# 3   99040                 mint              Mint Glazed Antipasto Dish Blue
# 4  808305              seedlip                Seedlip Grove 42 Alcohol Free
#
#                                   Brand_Product_Size  \
# 0          Em Wholefoods Hemp Oil Cold Pressed 250mL
# 1  Happy Little Camper Newborn Natural Nappies 36...
# 2            Spc Spaghetti Rich Tomato 140g x12 pack
# 3               Mint Glazed Antipasto Dish Blue each
# 4                Seedlip Grove 42 Alcohol Free 700mL
#
#                           COL Product Match Match Score  WOW Price  \
# 0      Soulseed Cold Pressed Hemp Oil 250mL          83      19.95
# 1                                                            14.00
# 2  SPC Spaghetti in Rich Tomato 4 pack 220g          83      10.50
# 3                                                             2.00
# 4                                                            50.00
#
#          WOW ppu       WOW Size WOW Specials WOW Category  \
# 0  $7.98 / 100ML          250mL                    Pantry
# 1    $0.39 / 1EA        36 pack                      Baby
# 2   $0.63 / 100G  140g x12 pack                    Pantry
# 3                          each                NOT LISTED
# 4    $71.43 / 1L          700mL                    Drinks
#
#                                          Product URL
# 0  https://www.woolworths.com.au/shop/productdeta...
# 1  https://www.woolworths.com.au/shop/productdeta...
# 2  https://www.woolworths.com.au/shop/productdeta...
# 3  https://www.woolworths.com.au/shop/productdeta...
# 4  https://www.woolworths.com.au/shop/productdeta...

# %%
wow_coles_fuzzymatched.to_csv('3. Fuzzy Matching/Token Sort/Woolworths_Coles.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Fuzzy Matching IGA and Coles

# %%
fuzzy_iga_coles = get_fuzzymatches(df_iga, df_coles).copy()

# %%
fuzzy_iga_coles['Product Match'] = fuzzy_iga_coles['FuzzyProduct Match'].apply(lambda x: x[0] if x is not None else '')
fuzzy_iga_coles['Match Score'] = fuzzy_iga_coles['FuzzyProduct Match'].apply(lambda x: int(x[1]) if x is not None else '')

# %%
fuzzy_iga_coles.head()
# Out:
#              SKU                           Brand_Product_Size  IGA Price  \
# 0  9300675009775                   Diet Coke Soft Drink 600ml       4.10
# 1           4155                           Granny Smith Apple       0.99
# 2           4156                              Pink Lady Apple       1.20
# 3  9310023141460  Helga’s Wraps Traditional White 8 Pack 560g       5.55
# 4  9310023141446        Helga’s Mixed Grain Wraps 8 Pack 560g       5.55
#
#           IGA ppu IGA Category  \
# 0  2.46 per litre       Drinks
# 1     5.50 per kg  Fruit & Veg
# 2     6.00 per kg  Fruit & Veg
# 3   0.99 per 100g       Bakery
# 4   0.99 per 100g       Bakery
#
#                                          Product URL  \
# 0  https://igashop.com.au/product/diet-coke-soft-...
# 1  https://igashop.com.au/product/granny-smith-ap...
# 2    https://igashop.com.au/product/pink-lady-apple/
# 3  https://igashop.com.au/product/helgas-wraps-tr...
# 4  https://igashop.com.au/product/helgas-mixed-gr...
#
#                                   FuzzyProduct Match  \
# 0  (Coca Cola Soft Drink Diet Coke Can 250mL, 72....
# 1                                               None
# 2                                               None
# 3  (Helga's Traditional White Wraps 8 pack 560g, ...
# 4  (Helga's Mixed Grain Wraps 8 pack 560g, 100.0,...
#
#                                  Product Match Match Score
# 0     Coca Cola Soft Drink Diet Coke Can 250mL          72
# 1
# 2
# 3  Helga's Traditional White Wraps 8 pack 560g         100
# 4        Helga's Mixed Grain Wraps 8 pack 560g         100

# %%
iga_coles_fuzzymatched = fuzzy_iga_coles[['SKU', 'Brand_Product_Size', 'Product Match', 'Match Score', 'IGA Price', 'IGA ppu', 'IGA Category', 'Product URL']]
iga_coles_fuzzymatched = iga_coles_fuzzymatched.rename(columns={'Product Match': 'COL Product Match'})

# %%
iga_coles_fuzzymatched.head()
# Out:
#              SKU                           Brand_Product_Size  \
# 0  9300675009775                   Diet Coke Soft Drink 600ml
# 1           4155                           Granny Smith Apple
# 2           4156                              Pink Lady Apple
# 3  9310023141460  Helga’s Wraps Traditional White 8 Pack 560g
# 4  9310023141446        Helga’s Mixed Grain Wraps 8 Pack 560g
#
#                              COL Product Match Match Score  IGA Price  \
# 0     Coca Cola Soft Drink Diet Coke Can 250mL          72       4.10
# 1                                                                0.99
# 2                                                                1.20
# 3  Helga's Traditional White Wraps 8 pack 560g         100       5.55
# 4        Helga's Mixed Grain Wraps 8 pack 560g         100       5.55
#
#           IGA ppu IGA Category  \
# 0  2.46 per litre       Drinks
# 1     5.50 per kg  Fruit & Veg
# 2     6.00 per kg  Fruit & Veg
# 3   0.99 per 100g       Bakery
# 4   0.99 per 100g       Bakery
#
#                                          Product URL
# 0  https://igashop.com.au/product/diet-coke-soft-...
# 1  https://igashop.com.au/product/granny-smith-ap...
# 2    https://igashop.com.au/product/pink-lady-apple/
# 3  https://igashop.com.au/product/helgas-wraps-tr...
# 4  https://igashop.com.au/product/helgas-mixed-gr...

# %%
iga_coles_fuzzymatched.to_csv('3. Fuzzy Matching/Token Sort/IGA_Coles.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## Fuzzy Matching IGA and Woolworths

# %%
fuzzy_iga_wow = get_fuzzymatches(df_iga, df_wow).copy()

# %%
fuzzy_iga_wow['Product Match'] = fuzzy_iga_wow['FuzzyProduct Match'].apply(lambda x: x[0] if x is not None else '')
fuzzy_iga_wow['Match Score'] = fuzzy_iga_wow['FuzzyProduct Match'].apply(lambda x: int(x[1]) if x is not None else '')

# %%
fuzzy_iga_wow.head()
# Out:
#              SKU                           Brand_Product_Size  IGA Price  \
# 0  9300675009775                   Diet Coke Soft Drink 600ml       4.10
# 1           4155                           Granny Smith Apple       0.99
# 2           4156                              Pink Lady Apple       1.20
# 3  9310023141460  Helga’s Wraps Traditional White 8 Pack 560g       5.55
# 4  9310023141446        Helga’s Mixed Grain Wraps 8 Pack 560g       5.55
#
#           IGA ppu IGA Category  \
# 0  2.46 per litre       Drinks
# 1     5.50 per kg  Fruit & Veg
# 2     6.00 per kg  Fruit & Veg
# 3   0.99 per 100g       Bakery
# 4   0.99 per 100g       Bakery
#
#                                          Product URL  \
# 0  https://igashop.com.au/product/diet-coke-soft-...
# 1  https://igashop.com.au/product/granny-smith-ap...
# 2    https://igashop.com.au/product/pink-lady-apple/
# 3  https://igashop.com.au/product/helgas-wraps-tr...
# 4  https://igashop.com.au/product/helgas-mixed-gr...
#
#                                   FuzzyProduct Match  \
# 0  (Coca-cola Diet Soft Drink Bottle 600mL, 75.0,...
# 1      (Fresh Granny Smith Apples each, 75.0, 13612)
# 2  (Fresh Pink Lady Apples each, 71.4285714285714...
# 3  (Helga's Wraps Traditional White 560g 8 pack, ...
# 4  (Helga's Wraps Mixed Grain 560g 8 pack, 100.0,...
#
#                                  Product Match Match Score
# 0       Coca-cola Diet Soft Drink Bottle 600mL          75
# 1               Fresh Granny Smith Apples each          75
# 2                  Fresh Pink Lady Apples each          71
# 3  Helga's Wraps Traditional White 560g 8 pack         100
# 4        Helga's Wraps Mixed Grain 560g 8 pack         100

# %%
iga_wow_fuzzymatched = fuzzy_iga_wow[['SKU', 'Brand_Product_Size', 'Product Match', 'Match Score', 'IGA Price', 'IGA ppu', 'IGA Category', 'Product URL']]
iga_wow_fuzzymatched = iga_wow_fuzzymatched.rename(columns={'Product Match': 'WOW Product Match'})

# %%
iga_wow_fuzzymatched.head()
# Out:
#              SKU                           Brand_Product_Size  \
# 0  9300675009775                   Diet Coke Soft Drink 600ml
# 1           4155                           Granny Smith Apple
# 2           4156                              Pink Lady Apple
# 3  9310023141460  Helga’s Wraps Traditional White 8 Pack 560g
# 4  9310023141446        Helga’s Mixed Grain Wraps 8 Pack 560g
#
#                              WOW Product Match Match Score  IGA Price  \
# 0       Coca-cola Diet Soft Drink Bottle 600mL          75       4.10
# 1               Fresh Granny Smith Apples each          75       0.99
# 2                  Fresh Pink Lady Apples each          71       1.20
# 3  Helga's Wraps Traditional White 560g 8 pack         100       5.55
# 4        Helga's Wraps Mixed Grain 560g 8 pack         100       5.55
#
#           IGA ppu IGA Category  \
# 0  2.46 per litre       Drinks
# 1     5.50 per kg  Fruit & Veg
# 2     6.00 per kg  Fruit & Veg
# 3   0.99 per 100g       Bakery
# 4   0.99 per 100g       Bakery
#
#                                          Product URL
# 0  https://igashop.com.au/product/diet-coke-soft-...
# 1  https://igashop.com.au/product/granny-smith-ap...
# 2    https://igashop.com.au/product/pink-lady-apple/
# 3  https://igashop.com.au/product/helgas-wraps-tr...
# 4  https://igashop.com.au/product/helgas-mixed-gr...

# %%
iga_wow_fuzzymatched.to_csv('3. Fuzzy Matching/Token Sort/IGA_Woolworths.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# * Token Sort with a score of 100 is accurate in matching the same product (It's just matching the 'tokens' i.e. the words, so order is irrelevant)
# * Token Set has the ability to match things like the following:
#     * Huggies Infant Size 2 Unisex 96 Nappies Jumbo Pack 1 pack (Coles) vs Huggies Jumbo Infant Nappies Nappies 96 pack (Woolworths)
